# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
# by default it uses the gemma:2b model, as i have downladed gemma:2b model using that here in this function which has 2048 dimesnsions
embeds = OllamaEmbeddings(model='gemma:2b')
# Out:
# /var/folders/r2/xlb4cnwx41s6_gwxxg2_8wx80000gn/T/ipykernel_3897/1484163191.py:1: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaEmbeddings``.
#   embeds = OllamaEmbeddings(model='gemma:2b')

# %%
r1 = embeds.embed_documents(["This is a test", "This is another test"])

# %%
len(r1[0])
# Out:
# 2048
